# %%
# %run FunctionNotebook.ipynb
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     702             fpath = arg_lst[0]
# --> 703             filename = file_finder(fpath)
#     704         except IndexError:
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/IPython/utils/path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'6_23.ipynb.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# ~/Desktop/Summer 2023/myx/FunctionNotebook.ipynb in <module>
# ----> 1 get_ipython().run_line_magic('run', '6_23.ipynb')
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2349                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2350             with self.builtin_trap:
# -> 2351                 result = fn(*args, **kwargs)
#    2352             return result
#    2353
#
# <decorator-gen-52> in run(self, parameter_s, runner, file_finder)
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     712             if os.name == 'nt' and re.match(r"^'.*'$",fpath):
#     713                 warn('For Windows, use double quotes to wrap a filename: %run "mypath\\myfile.py"')
# --> 714             raise Exception(msg)
#     715         except TypeError:
#     716             if fpath in sys.meta_path:
#
# Exception: File `'6_23.ipynb.py'` not found.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     702             fpath = arg_lst[0]
# --> 703             filename = file_finder(fpath)
#     704         except IndexError:
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/IPython/utils/path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'6_23.ipynb.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# /var/folders/kp/n_rvgv6d06q574mr9lfv6sp00000gn/T/ipykernel_4162/2746177973.py in <module>
# ----> 1 get_ipython().run_line_magic('run', 'FunctionNotebook.ipynb')
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2349                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2350             with self.builtin_trap:
# -> 2351                 result = fn(*args, **kwargs)
#    2352             return result
#    2353
#
# <decorator-gen-52> in run(self, parameter_s, runner, file_finder)
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     722             with preserve_keys(self.shell.user_ns, '__file__'):
#     723                 self.shell.user_ns['__file__'] = filename
# --> 724                 self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     725             return
#     726
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/IPython/core/interactiveshell.py in safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2836                     result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2837                     if raise_exceptions:
# -> 2838                         result.raise_error()
#    2839                     elif not result.success:
#    2840                         break
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/IPython/core/interactiveshell.py in raise_error(self)
#     330             raise self.error_before_exec
#     331         if self.error_in_exec is not None:
# --> 332             raise self.error_in_exec
#     333
#     334     def __repr__(self):
#
#     [... skipping hidden 1 frame]
#
# /var/folders/kp/n_rvgv6d06q574mr9lfv6sp00000gn/T/ipykernel_4162/2968976359.py in <module>
# ----> 1 get_ipython().run_line_magic('run', '6_23.ipynb')
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2349                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2350             with self.builtin_trap:
# -> 2351                 result = fn(*args, **kwargs)
#    2352             return result
#    2353
#
# <decorator-gen-52> in run(self, parameter_s, runner, file_finder)
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     712             if os.name == 'nt' and re.match(r"^'.*'$",fpath):
#     713                 warn('For Windows, use double quotes to wrap a filename: %run "mypath\\myfile.py"')
# --> 714             raise Exception(msg)
#     715         except TypeError:
#     716             if fpath in sys.meta_path:
#
# Exception: File `'6_23.ipynb.py'` not found.

# %% [markdown]
# ## 7/6:

# %% [markdown]
# ### How bushy is "bushy enough" to move focus out of center?

# %%
A = double_broom_constructor(5,14,3)
A.show()
print(min_pessimal(A))
print("- - - - - - - - - - - - - - - - - -")
print(hitting_time_matrix(A))
# Out:
# Graphics object consisting of 42 graphics primitives
# 28
# - - - - - - - - - - - - - - - - - -
# [  0   1  30  61  94 133  40  40  40  40  40  40  40  40  40  40  40  40  40 133 133]
# [ 39   0  29  60  93 132  39  39  39  39  39  39  39  39  39  39  39  39  39 132 132]
# [ 50  11   0  31  64 103  50  50  50  50  50  50  50  50  50  50  50  50  50 103 103]
# [ 59  20   9   0  33  72  59  59  59  59  59  59  59  59  59  59  59  59  59  72  72]
# [ 66  27  16   7   0  39  66  66  66  66  66  66  66  66  66  66  66  66  66  39  39]
# [ 67  28  17   8   1   0  67  67  67  67  67  67  67  67  67  67  67  67  67  40  40]
# [ 40   1  30  61  94 133   0  40  40  40  40  40  40  40  40  40  40  40  40 133 133]
# [ 40   1  30  61  94 133  40   0  40  40  40  40  40  40  40  40  40  40  40 133 133]
# [ 40   1  30  61  94 133  40  40   0  40  40  40  40  40  40  40  40  40  40 133 133]
# [ 40   1  30  61  94 133  40  40  40   0  40  40  40  40  40  40  40  40  40 133 133]
# [ 40   1  30  61  94 133  40  40  40  40   0  40  40  40  40  40  40  40  40 133 133]
# [ 40   1  30  61  94 133  40  40  40  40  40   0  40  40  40  40  40  40  40 133 133]
58  58  58  58  58  58  58  58  58  58  58  58  58  58  58  58  58  58   0]

# %% [markdown]
# ### when do we swap from broom end to spork end?

# %%
A = double_broom_constructor(7,1,8)
A.show()
B = double_broom_constructor(7,2,7)
B.show()
C = double_broom_constructor(7,3,6)
C.show()
D = double_broom_constructor(7,4,5)
D.show()
# Out:
# Graphics object consisting of 30 graphics primitives
# Graphics object consisting of 30 graphics primitives
# Graphics object consisting of 30 graphics primitives
# Graphics object consisting of 30 graphics primitives

# %%
print(hitting_time_matrix(A))
print("- - - - - - - - - - - - - - -")
print(min_pessimal(A))
print("- - - - - - - - - - - - - - -")
print(hitting_time_matrix(B))
print("- - - - - - - - - - - - - - -")
print(min_pessimal(B))
print("- - - - - - - - - - - - - - -")
print(hitting_time_matrix(C))
print("- - - - - - - - - - - - - - -")
print(min_pessimal(C))
print("- - - - - - - - - - - - - - -")
print(hitting_time_matrix(D))
print("- - - - - - - - - - - - - - -")
print(min_pessimal(D))
# Out:
# [  0   1   4   9  16  25  36  63  63  63  63  63  63  63  63]
# [ 27   0   3   8  15  24  35  62  62  62  62  62  62  62  62]
# [ 52  25   0   5  12  21  32  59  59  59  59  59  59  59  59]
# [ 75  48  23   0   7  16  27  54  54  54  54  54  54  54  54]
# [ 96  69  44  21   0   9  20  47  47  47  47  47  47  47  47]
# [115  88  63  40  19   0  11  38  38  38  38  38  38  38  38]
# [132 105  80  57  36  17   0  27  27  27  27  27  27  27  27]
# [133 106  81  58  37  18   1   0  28  28  28  28  28  28  28]
# [133 106  81  58  37  18   1  28   0  28  28  28  28  28  28]
# [133 106  81  58  37  18   1  28  28   0  28  28  28  28  28]
# [133 106  81  58  37  18   1  28  28  28   0  28  28  28  28]
# [133 106  81  58  37  18   1  28  28  28  28   0  28  28  28]
# [133 106  81  58  37  18   1  28  28  28  28  28   0  28  28]
# [133 106  81  58  37  18   1  28  28  28  28  28  28   0  28]
# [133 106  81  58  37  18   1  28  28  28  28  28  28  28   0]
# - - - - - - - - - - - - - - -
# 25
# - - - - - - - - - - - - - - -
# [  0   1   6  13  22  33  46  73  28  73  73  73  73  73  73]
# [ 27   0   5  12  21  32  45  72  27  72  72  72  72  72  72]
# [ 50  23   0   7  16  27  40  67  50  67  67  67  67  67  67]
# [ 71  44  21   0   9  20  33  60  71  60  60  60  60  60  60]
# [ 90  63  40  19   0  11  24  51  90  51  51  51  51  51  51]
# [107  80  57  36  17   0  13  40 107  40  40  40  40  40  40]
# [122  95  72  51  32  15   0  27 122  27  27  27  27  27  27]
# [123  96  73  52  33  16   1   0 123  28  28  28  28  28  28]
# [ 28   1   6  13  22  33  46  73   0  73  73  73  73  73  73]
# [123  96  73  52  33  16   1  28 123   0  28  28  28  28  28]
# [123  96  73  52  33  16   1  28 123  28   0  28  28  28  28]
# [123  96  73  52  33  16   1  28 123  28  28   0  28  28  28]
# [123  96  73  52  33  16   1  28 123  28  28  28   0  28  28]
# [123  96  73  52  33  16   1  28 123  28  28  28  28   0  28]
# [123  96  73  52  33  16   1  28 123  28  28  28  28  28   0]
# - - - - - - - - - - - - - - -
# 33
# - - - - - - - - - - - - - - -
# [  0   1   8  17  28  41  56  83  28  28  83  83  83  83  83]
# [ 27   0   7  16  27  40  55  82  27  27  82  82  82  82  82]
# [ 48  21   0   9  20  33  48  75  48  48  75  75  75  75  75]
# [ 67  40  19   0  11  24  39  66  67  67  66  66  66  66  66]
# [ 84  57  36  17   0  13  28  55  84  84  55  55  55  55  55]
# [ 99  72  51  32  15   0  15  42  99  99  42  42  42  42  42]
# [112  85  64  45  28  13   0  27 112 112  27  27  27  27  27]
# [113  86  65  46  29  14   1   0 113 113  28  28  28  28  28]
# [ 28   1   8  17  28  41  56  83   0  28  83  83  83  83  83]
# [ 28   1   8  17  28  41  56  83  28   0  83  83  83  83  83]
# [113  86  65  46  29  14   1  28 113 113   0  28  28  28  28]
# [113  86  65  46  29  14   1  28 113 113  28   0  28  28  28]
# [113  86  65  46  29  14   1  28 113 113  28  28   0  28  28]
# [113  86  65  46  29  14   1  28 113 113  28  28  28   0  28]
# [113  86  65  46  29  14   1  28 113 113  28  28  28  28   0]
# - - - - - - - - - - - - - - -
# 29
# - - - - - - - - - - - - - - -
# [  0   1  10  21  34  49  66  93  28  28  28  93  93  93  93]
# [ 27   0   9  20  33  48  65  92  27  27  27  92  92  92  92]
# [ 46  19   0  11  24  39  56  83  46  46  46  83  83  83  83]
# [ 63  36  17   0  13  28  45  72  63  63  63  72  72  72  72]
# [ 78  51  32  15   0  15  32  59  78  78  78  59  59  59  59]
# [ 91  64  45  28  13   0  17  44  91  91  91  44  44  44  44]
# [102  75  56  39  24  11   0  27 102 102 102  27  27  27  27]
# [103  76  57  40  25  12   1   0 103 103 103  28  28  28  28]
# [ 28   1  10  21  34  49  66  93   0  28  28  93  93  93  93]
# [ 28   1  10  21  34  49  66  93  28   0  28  93  93  93  93]
# [ 28   1  10  21  34  49  66  93  28  28   0  93  93  93  93]
# [103  76  57  40  25  12   1  28 103 103 103   0  28  28  28]
# [103  76  57  40  25  12   1  28 103 103 103  28   0  28  28]
# [103  76  57  40  25  12   1  28 103 103 103  28  28   0  28]
# [103  76  57  40  25  12   1  28 103 103 103  28  28  28   0]
# - - - - - - - - - - - - - - -
# 34

# %%
A = double_broom_constructor(7,1,7)
A.show()
B = double_broom_constructor(7,2,6)
B.show()
C = double_broom_constructor(7,3,5)
C.show()
D = double_broom_constructor(7,4,4)
D.show()
# Out:
# Graphics object consisting of 28 graphics primitives
# Graphics object consisting of 28 graphics primitives
# Graphics object consisting of 28 graphics primitives
# Graphics object consisting of 28 graphics primitives

# %%
print(hitting_time_matrix(A))
print("- - - - - - - - - - - - - - -")
print(min_pessimal(A))
print("- - - - - - - - - - - - - - -")
print(hitting_time_matrix(B))
print("- - - - - - - - - - - - - - -")
print(min_pessimal(B))
print("- - - - - - - - - - - - - - -")
print(hitting_time_matrix(C))
print("- - - - - - - - - - - - - - -")
print(min_pessimal(C))
print("- - - - - - - - - - - - - - -")
print(hitting_time_matrix(D))
print("- - - - - - - - - - - - - - -")
print(min_pessimal(D))
# Out:
# [  0   1   4   9  16  25  36  61  61  61  61  61  61  61]
# [ 25   0   3   8  15  24  35  60  60  60  60  60  60  60]
# [ 48  23   0   5  12  21  32  57  57  57  57  57  57  57]
# [90 65 48 33 20  9  0 25 90 90 90 25 25 25]
# [91 66 49 34 21 10  1  0 91 91 91 26 26 26]
# [26  1 10 21 34 49 66 91  0 26 26 91 91 91]
# [26  1 10 21 34 49 66 91 26  0 26 91 91 91]
# [26  1 10 21 34 49 66 91 26 26  0 91 91 91]
# [91 66 49 34 21 10  1 26 91 91 91  0 26 26]
# [91 66 49 34 21 10  1 26 91 91 91 26  0 26]
# [91 66 49 34 21 10  1 26 91 91 91 26 26  0]
# - - - - - - - - - - - - - - -
# 34

# %%
A = double_broom_constructor(7,1,6)
A.show()
B = double_broom_constructor(7,2,5)
B.show()
C = double_broom_constructor(7,3,4)
C.show()
# Out:
# Graphics object consisting of 26 graphics primitives
# Graphics object consisting of 26 graphics primitives
# Graphics object consisting of 26 graphics primitives

# %%
print(hitting_time_matrix(A))
print("- - - - - - - - - - - - - - -")
print(min_pessimal(A))
print("- - - - - - - - - - - - - - -")
print(hitting_time_matrix(B))
print("- - - - - - - - - - - - - - -")
print(min_pessimal(B))
print("- - - - - - - - - - - - - - -")
print(hitting_time_matrix(C))
print("- - - - - - - - - - - - - - -")
print(min_pessimal(C))
print("- - - - - - - - - - - - - - -")
# Out:
# [  0   1   4   9  16  25  36  59  59  59  59  59  59]
# [ 23   0   3   8  15  24  35  58  58  58  58  58  58]
# [ 44  21   0   5  12  21  32  55  55  55  55  55  55]
# [ 63  40  19   0   7  16  27  50  50  50  50  50  50]
# [ 80  57  36  17   0   9  20  43  43  43  43  43  43]
# [ 95  72  51  32  15   0  11  34  34  34  34  34  34]
# [108  85  64  45  28  13   0  23  23  23  23  23  23]
# [109  86  65  46  29  14   1   0  24  24  24  24  24]
# [109  86  65  46  29  14   1  24   0  24  24  24  24]
# [109  86  65  46  29  14   1  24  24   0  24  24  24]
# [109  86  65  46  29  14   1  24  24  24   0  24  24]
# [109  86  65  46  29  14   1  24  24  24  24   0  24]
# [109  86  65  46  29  14   1  24  24  24  24  24   0]
# - - - - - - - - - - - - - - -
# 25
# - - - - - - - - - - - - - - -
# [ 0  1  6 13 22 33 46 69 24 69 69 69 69]
# [23  0  5 12 21 32 45 68 23 68 68 68 68]
# [42 19  0  7 16 27 40 63 42 63 63 63 63]
# [59 36 17  0  9 20 33 56 59 56 56 56 56]
# [74 51 32 15  0 11 24 47 74 47 47 47 47]
# [87 64 45 28 13  0 13 36 87 36 36 36 36]
# [98 75 56 39 24 11  0 23 98 23 23 23 23]
# [99 76 57 40 25 12  1  0 99 24 24 24 24]
# [24  1  6 13 22 33 46 69  0 69 69 69 69]
# [99 76 57 40 25 12  1 24 99  0 24 24 24]
# [99 76 57 40 25 12  1 24 99 24  0 24 24]
# [99 76 57 40 25 12  1 24 99 24 24  0 24]
# [99 76 57 40 25 12  1 24 99 24 24 24  0]
# - - - - - - - - - - - - - - -
# 25
# - - - - - - - - - - - - - - -
# [ 0  1  8 17 28 41 56 79 24 24 79 79 79]
# [23  0  7 16 27 40 55 78 23 23 78 78 78]
# [40 17  0  9 20 33 48 71 40 40 71 71 71]
# [105  76  57  40  25  12   1  30 105 105 105 105  30  30   0  30]
# [105  76  57  40  25  12   1  30 105 105 105 105  30  30  30   0]

# %%
min_pessimal(E)
# Out:
# 40

# %%
F = A.copy()
F.delete_vertex(15)
F.show()
hitting_time_matrix(F)
# Out:
# Graphics object consisting of 30 graphics primitives
# [  0   1   4  17  36  59  84 111  31  31  31  31  44  44  63]
# [ 27   0   3  16  35  58  83 110  30  30  30  30  43  43  62]
# [ 52  25   0  13  32  55  80 107  27  27  27  27  40  40  59]
# [ 67  40  15   0  19  42  67  94  42  42  42  42  27  27  46]
# [ 76  49  24   9   0  23  48  75  51  51  51  51  36  36  27]
# [ 81  54  29  14   5   0  25  52  56  56  56  56  41  41  32]
# [ 84  57  32  17   8   3   0  27  59  59  59  59  44  44  35]
# [ 85  58  33  18   9   4   1   0  60  60  60  60  45  45  36]
# [ 53  26   1  14  33  56  81 108   0  28  28  28  41  41  60]
# [ 53  26   1  14  33  56  81 108  28   0  28  28  41  41  60]
# [ 53  26   1  14  33  56  81 108  28  28   0  28  41  41  60]
# [ 53  26   1  14  33  56  81 108  28  28  28   0  41  41  60]
# [ 68  41  16   1  20  43  68  95  43  43  43  43   0  28  47]
# [ 68  41  16   1  20  43  68  95  43  43  43  43  28   0  47]
# [ 77  50  25  10   1  24  49  76  52  52  52  52  37  37   0]

# %%
min_pessimal(F)
# Out:
# 18

# %%
G = F.copy()
G.delete_edge(2,8)
G.delete_edge(2,9)
G.add_edge(1,8)
G.add_edge(1,9)
G.delete_edge(4,14)
G.add_edge(6,14)
G.show()
hitting_time_matrix(G)
# Out:
# Graphics object consisting of 30 graphics primitives
# [  0   1   8  21  40  61  84 111  28  28  35  35  48  48 111]
# [ 27   0   7  20  39  60  83 110  27  27  34  34  47  47 110]
# [ 48  21   0  13  32  53  76 103  48  48  27  27  40  40 103]
# [ 63  36  15   0  19  40  63  90  63  63  42  42  27  27  90]
# [ 72  45  24   9   0  21  44  71  72  72  51  51  36  36  71]
# [ 79  52  31  16   7   0  23  50  79  79  58  58  43  43  50]
# [ 84  57  36  21  12   5   0  27  84  84  63  63  48  48  27]
# [ 85  58  37  22  13   6   1   0  85  85  64  64  49  49  28]
# [ 28   1   8  21  40  61  84 111   0  28  35  35  48  48 111]
# [ 28   1   8  21  40  61  84 111  28   0  35  35  48  48 111]
# [ 49  22   1  14  33  54  77 104  49  49   0  28  41  41 104]
# [ 49  22   1  14  33  54  77 104  49  49  28   0  41  41 104]
# [ 64  37  16   1  20  41  64  91  64  64  43  43   0  28  91]
# [ 64  37  16   1  20  41  64  91  64  64  43  43  28   0  91]
# [ 85  58  37  22  13   6   1  28  85  85  64  64  49  49   0]

# %%
min_pessimal(G)
# Out:
# 22

# %%
H = G.copy()
H.delete_edge(2,10)
H.delete_edge(2,11)
H.delete_edge(3,12)
H.delete_edge(3,13)
H.add_edge(1,10)
H.add_edge(1,11)
H.add_edge(1,12)
H.add_edge(1,13)
H.show()
hitting_time_matrix(H)
# Out:
# Graphics object consisting of 30 graphics primitives
# [  0   1  16  33  52  73  96 123  28  28  28  28  28  28 123]
# [17  8  1 18 18  0 28 41 58 58]
# [ 7 16 27 44 44 44  0 13 30 30]
# [12 21 32 49 49 49  5  0 17 17]
# [13 22 33 50 50 50  6  1  0 18]
# [13 22 33 50 50 50  6  1 18  0]
# Graphics object consisting of 20 graphics primitives
# [ 0  9 20 37 37 37 11 26 43 28]
# [ 9  0 11 28 28 28 20 35 52 37]
# [16  7  0 17 17 17 27 42 59 44]
# [17  8  1  0 18 18 28 43 60 45]
# [17  8  1 18  0 18 28 43 60 45]
# [17  8  1 18 18  0 28 43 60 45]
# [ 7 16 27 44 44 44  0 15 32 17]
# [10 19 30 47 47 47  3  0 17 20]
# [11 20 31 48 48 48  4  1  0 21]
# [ 8 17 28 45 45 45  1 16 33  0]
# Graphics object consisting of 20 graphics primitives
# [ 0  9 20 37 37 37 13 28 45 17]
# [ 9  0 11 28 28 28 22 37 54 26]
# [16  7  0 17 17 17 29 44 61 33]
# [17  8  1  0 18 18 30 45 62 34]
# [17  8  1 18  0 18 30 45 62 34]
# [17  8  1 18 18  0 30 45 62 34]
# [ 5 14 25 42 42 42  0 15 32 22]
# [ 8 17 28 45 45 45  3  0 17 25]
# [ 9 18 29 46 46 46  4  1  0 26]
# [ 1 10 21 38 38 38 14 29 46  0]
# 17

# %%
double_broom_constructor(6,3,2)
# Out:
# Graph on 10 vertices

# %%
for broom in range(1,6):
    for spork in range(1,6):
        A = double_broom_constructor(6, broom, spork)
        A.show()
        print(min_pessimal(A))
# Out:
# Graphics object consisting of 14 graphics primitives
# 9
# Graphics object consisting of 16 graphics primitives
# 13
# Graphics object consisting of 18 graphics primitives
# 16
# Graphics object consisting of 20 graphics primitives
# 16
# Graphics object consisting of 22 graphics primitives
# 16
# Graphics object consisting of 16 graphics primitives
# 13
# Graphics object consisting of 18 graphics primitives
# 13
# Graphics object consisting of 20 graphics primitives
# 17
# Graphics object consisting of 22 graphics primitives
# 21
# Graphics object consisting of 24 graphics primitives
# 22
# Graphics object consisting of 18 graphics primitives
# 16
# Graphics object consisting of 20 graphics primitives
# 17
# Graphics object consisting of 22 graphics primitives
# 17
# Graphics object consisting of 24 graphics primitives
# 21
# Graphics object consisting of 26 graphics primitives
# 25
# Graphics object consisting of 20 graphics primitives
# 16
# Graphics object consisting of 22 graphics primitives
# 21
# Graphics object consisting of 24 graphics primitives
# 21
# Graphics object consisting of 26 graphics primitives
# 21
# Graphics object consisting of 28 graphics primitives
# 25
# Graphics object consisting of 22 graphics primitives
# 16
# Graphics object consisting of 24 graphics primitives
# 22
# Graphics object consisting of 26 graphics primitives
# 25
# Graphics object consisting of 28 graphics primitives
# 25
# Graphics object consisting of 30 graphics primitives
# 25

# %%
n = 9
d = 5

for i in range(1,int((n-d+2)/2)+1):
    A = double_broom_constructor(d,n-d-i+1,i)
    A.show()
    print(min_pessimal(A))
# Out:
# Graphics object consisting of 18 graphics primitives
# 10
# Graphics object consisting of 18 graphics primitives
# 13
# Graphics object consisting of 18 graphics primitives
# 13

# %%
def sporked_broom_hitting_time_odd_d(d,b,s):
    spork_side = 2*(d-((d/2)-1)-1)*(d-((d/2)-1)+(s))-(d-((d/2)-1))^2+2
    broom_side = 2*(d-(d/2)-1)*(d-(d/2)+(b))-(d-(d/2))^2+2
    print(spork_side)
    print(broom_side)
    hit_time = min(spork_side, broom_side)
    return hit_time

# %%
def spork_broom_simple(d,b,s):
    spork_side = (d/2)^2 + (d*s) + 1
    broom_side = (d/2)^2 + ((d-2)*(b-1))
    print(spork_side)
    print(broom_side)
    hit_time = min(spork_side, broom_side)
    return hit_time

# %%
sporked_broom_hitting_time(5,3,2)
# Out:
# 69/4
# 49/4
# 49/4

# %%
spork_broom_simple(6,3,2)
# Out:
# 22
# 17
# 17

# %%
spork_broom_simple(8,6,4)
# Out:
# 49
# 46
# 46

# %%
sporked_broom_hitting_time(6,5,3)
# Out:
# 28
# 25
# 25

# %%
A = double_broom_constructor(6, 4, 0)
A.show()
hitting_time_matrix(A)
# Out:
# Graphics object consisting of 20 graphics primitives
# [ 0  1 10 21 34 49 66 18 18 18]
# [17  0  9 20 33 48 65 17 17 17]
# [26  9  0 11 24 39 56 26 26 26]
# [33 16  7  0 13 28 45 33 33 33]
# [38 21 12  5  0 15 32 38 38 38]
# [41 24 15  8  3  0 17 41 41 41]
# [42 25 16  9  4  1  0 42 42 42]
# [18  1 10 21 34 49 66  0 18 18]
# [18  1 10 21 34 49 66 18  0 18]
# [18  1 10 21 34 49 66 18 18  0]

# %% [markdown]
# ## 6/23:

# %% [markdown]
# ### formula for min pess time on a lever graph

# %%
def min_pess_time_lever_graph(d, i, l):
    list_of_pess_times = []
    for j in range(1, d):
        if j < i:
            H_0 = j^2
            H_d = (d-j)^2 + (2*l*(i-j))
        elif j == i:
            H_0 = i^2
            H_d = (d-j)^2
        else:
            H_0 = j^2 + 2*l*(j-i)
            H_d = (d-j)^2
        j_pess = max(H_0, H_d)
        list_of_pess_times.append(j_pess)
    min_pess = min(list_of_pess_times)
    vertex = list_of_pess_times.index(min_pess)
    return ("the pessimal time is", min_pess, "which occures when j =", vertex+1)

# %%
min_pess_time_lever_graph(7,5,10)
# Out:
# ('the pessimal time is', 25, 'which occures when j =', 5)

# %%
#min_min_pessimal(13,7)

# %% [markdown]
# ## 6/22:

# %% [markdown]
# ### Lemma about min for lever graph

# %%
def lever_maker(diameter, vertex, leaves):
        path = graphs.PathGraph(diameter+1)
        for i in range(leaves):
            path.add_edge(vertex, diameter+i+leaves)
        lever_string = path.graph6_string()
        lever = Graph(lever_string)
        return lever

# %%
def double_lever_maker(diameter, left_vertex, right_vertex, left_leaves, right_leaves):
        path = graphs.PathGraph(diameter+1)
        for i in range(left_leaves):
            path.add_edge(left_vertex, diameter+i+left_leaves)
        for i in range(right_leaves):
            path.add_edge(right_vertex, right_leaves+diameter+i+left_leaves)
        double_lever_string = path.graph6_string()
        double_lever = Graph(double_lever_string)
        return double_lever

# %%
A = double_lever_maker(7,3,4,5,6)
A.show()
print(min_pessimal(A))
print(hitting_time_matrix(A))
B = lever_maker(7,3,11)
B.show()
print(min_pessimal(B))
C = lever_maker(7,4,11)
C.show()
print(min_pessimal(C))
# Out:
# Graphics object consisting of 38 graphics primitives
# 26
# [  0   1   4   9  26  57  90 125  44  44  44  44  44  61  61  61  61  61  61]
# [ 35   0   3   8  25  56  89 124  43  43  43  43  43  60  60  60  60  60  60]
# [ 68  33   0   5  22  53  86 121  40  40  40  40  40  57  57  57  57  57  57]
# [ 99  64  31   0  17  48  81 116  35  35  35  35  35  52  52  52  52  52  52]
# [118  83  50  19   0  31  64  99  54  54  54  54  54  35  35  35  35  35  35]
# [123  88  55  24   5   0  33  68  59  59  59  59  59  40  40  40  40  40  40]
# [126  91  58  27   8   3   0  35  62  62  62  62  62  43  43  43  43  43  43]
# [127  92  59  28   9   4   1   0  63  63  63  63  63  44  44  44  44  44  44]
# [100  65  32   1  18  49  82 117   0  36  36  36  36  53  53  53  53  53  53]
# [100  65  32   1  18  49  82 117  36   0  36  36  36  53  53  53  53  53  53]
# [100  65  32   1  18  49  82 117  36  36   0  36  36  53  53  53  53  53  53]
# [100  65  32   1  18  49  82 117  36  36  36   0  36  53  53  53  53  53  53]
# [100  65  32   1  18  49  82 117  36  36  36  36   0  53  53  53  53  53  53]
# [119  84  51  20   1  32  65 100  55  55  55  55  55   0  36  36  36  36  36]
# [119  84  51  20   1  32  65 100  55  55  55  55  55  36   0  36  36  36  36]
# [119  84  51  20   1  32  65 100  55  55  55  55  55  36  36   0  36  36  36]
# [119  84  51  20   1  32  65 100  55  55  55  55  55  36  36  36   0  36  36]
# [119  84  51  20   1  32  65 100  55  55  55  55  55  36  36  36  36   0  36]
# [119  84  51  20   1  32  65 100  55  55  55  55  55  36  36  36  36  36   0]
# Graphics object consisting of 38 graphics primitives
# 16
# Graphics object consisting of 38 graphics primitives
# 16

# %%
A = lever_maker(6,2,3)
A.show()
hitting_time(A,6,2)
# Out:
# Graphics object consisting of 20 graphics primitives
# 16

# %%
min_pessimal(A)
# Out:
# 41

# %%
for i in range(0,12):
    A = lever_maker(7,i,6)
    print(i, min_pessimal(A))
# Out:
# 0 29
# 1 25
# 2 21
# 3 16
# 4 16
# 5 21
# 6 25
# 7 29
# ---------------------------------------------------------------------------
# SignError                                 Traceback (most recent call last)
# /var/folders/kp/n_rvgv6d06q574mr9lfv6sp00000gn/T/ipykernel_42240/3261435055.py in <module>
#       1 for i in range(Integer(0),Integer(12)):
#       2     A = lever_maker(Integer(7),i,Integer(6))
# ----> 3     print(i, min_pessimal(A))
#
# /var/folders/kp/n_rvgv6d06q574mr9lfv6sp00000gn/T/ipykernel_42240/2843574859.py in min_pessimal(G)
#      41
#      42 def min_pessimal(G): #finds the min pessimal value for a graph G
# ---> 43     matrix = hitting_time_matrix(G).transpose()
#      44     list_of_pessimals = [] #placeholder empty list
#      45     for row in matrix: #for each vertex
#
# /var/folders/kp/n_rvgv6d06q574mr9lfv6sp00000gn/T/ipykernel_42240/2843574859.py in hitting_time_matrix(string)
#      18     for i in G.vertices(): #for each vertex
#      19         for j in G.vertices(): #find the hitting time to each other vertex
# ---> 20             matrix[i,j]=hitting_time(G,i,j) #put that into a matrix
#      21
#      22     return matrix
#
# /var/folders/kp/n_rvgv6d06q574mr9lfv6sp00000gn/T/ipykernel_42240/2843574859.py in hitting_time(G, i, j)
#       8     total_time = Integer(0)
#       9     for k in G.vertices(): # sum over all k
# ---> 10         one_iteration = length_shared_path(G, i, k, j) * G.degree(k) #multiply the length times the degree for one k
#      11         total_time = total_time + one_iteration #add it to total
#      12     return total_time
#
# /var/folders/kp/n_rvgv6d06q574mr9lfv6sp00000gn/T/ipykernel_42240/2843574859.py in length_shared_path(G, i, k, j)
#       3
#       4 def length_shared_path(G, i, k, j): #computes the length of the shared path between the vertices i and j and the vertices k and j.
# ----> 5     return ((Integer(1)/Integer(2)) * (G.distance(i, j) + G.distance(k, j) - G.distance(i,k)))
#       6
#       7 def hitting_time(G, i, j): #computes the hitting time between two vertices i and j in graph G.
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/sage/structure/element.pyx in sage.structure.element.Element.__sub__ (build/cythonized/sage/structure/element.c:11569)()
#    1354         cdef int cl = classify_elements(left, right)
#    1355         if HAVE_SAME_PARENT(cl):
# -> 1356             return (<Element>left)._sub_(right)
#    1357         if BOTH_ARE_ELEMENT(cl):
#    1358             return coercion_model.bin_op(left, right, sub)
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/sage/structure/element.pyx in sage.structure.element.ModuleElement._sub_ (build/cythonized/sage/structure/element.c:15858)()
#    2387         return coercion_model.bin_op(self, n, add)
#    2388
# -> 2389     cpdef _sub_(self, other):
#    2390         """
#    2391         Default implementation of subtraction using addition and
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/sage/rings/infinity.py in _sub_(self, other)
#     425                 raise SignError("cannot subtract unsigned infinities")
#     426             elif self._sign == other._sign:
# --> 427                 raise SignError("cannot add infinity to minus infinity")
#     428         return self
#     429
#
# SignError: cannot add infinity to minus infinity

# %%
A = lever_maker(6,3,10)
A.show()
hitting_time_matrix(A)
# Out:
# Graphics object consisting of 36 graphics primitives
# [  0   1   4   9  36  65  96 129  42  42  42  42  42  42  42  42  42  42]
# [ 33   0   3   8  35  64  95 128  41  41  41  41  41  41  41  41  41  41]
# [ 64  31   0   5  32  61  92 125  38  38  38  38  38  38  38  38  38  38]
# [ 93  60  29   0  27  56  87 120  33  33  33  33  33  33  33  33  33  33]
# [100  67  36   7   0  29  60  93  40  40  40  40  40  40  40  40  40  40]
# [105  72  41  12   5   0  31  64  45  45  45  45  45  45  45  45  45  45]
# [108  75  44  15   8   3   0  33  48  48  48  48  48  48  48  48  48  48]
# [109  76  45  16   9   4   1   0  49  49  49  49  49  49  49  49  49  49]
# [ 94  61  30   1  28  57  88 121   0  34  34  34  34  34  34  34  34  34]
# [ 94  61  30   1  28  57  88 121  34   0  34  34  34  34  34  34  34  34]
# [ 94  61  30   1  28  57  88 121  34  34   0  34  34  34  34  34  34  34]
# [ 94  61  30   1  28  57  88 121  34  34  34   0  34  34  34  34  34  34]
# %%
min_pessimal(H)
# Out:
# 16

# %%
Z = Graph({0:[1],1:[2,7],2:[3],3:[4],4:[5],5:[6,8,9,10,11]})
Z.show()
hitting_time_matrix(Z)
# Out:
# Graphics object consisting of 24 graphics primitives
# [ 0  1  6 13 22 33 54 22 54 54 54 54]
# [21  0  5 12 21 32 53 21 53 53 53 53]
# [38 17  0  7 16 27 48 38 48 48 48 48]
# [53 32 15  0  9 20 41 53 41 41 41 41]
# [66 45 28 13  0 11 32 66 32 32 32 32]
# [77 56 39 24 11  0 21 77 21 21 21 21]
# [78 57 40 25 12  1  0 78 22 22 22 22]
# [22  1  6 13 22 33 54  0 54 54 54 54]
# [78 57 40 25 12  1 22 78  0 22 22 22]
# [78 57 40 25 12  1 22 78 22  0 22 22]
# [78 57 40 25 12  1 22 78 22 22  0 22]
# [78 57 40 25 12  1 22 78 22 22 22  0]

# %%
min(78,57,40,25,22,33,54,78,54,54,54,54)

# %%
min_pessimal(Z)
# Out:
# 22

# %%
Y = Z.copy()
Y.delete_edge(1,7)
Y.add_edge(2,7)
Y.delete_edge(5,8)
Y.add_edge(4,8)
Y.show()
hitting_time_matrix(Y)
# Out:
# Graphics object consisting of 24 graphics primitives
# [ 0  1  4 11 20 33 54 25 41 54 54 54]
# [21  0  3 10 19 32 53 24 40 53 53 53]
# [40 19  0  7 16 29 50 21 37 50 50 50]
# [55 34 15  0  9 22 43 36 30 43 43 43]
# [68 47 28 13  0 13 34 49 21 34 34 34]
# [77 56 37 22  9  0 21 58 30 21 21 21]
# [78 57 38 23 10  1  0 59 31 22 22 22]
# [41 20  1  8 17 30 51  0 38 51 51 51]
# [69 48 29 14  1 14 35 50  0 35 35 35]
# [78 57 38 23 10  1 22 59 31  0 22 22]
# [78 57 38 23 10  1 22 59 31 22  0 22]
# [78 57 38 23 10  1 22 59 31 22 22  0]

# %%
min_pessimal(Y)
# Out:
# 20

# %%
X = Y.copy()
X.delete_edge(2,7)
X.add_edge(4,7)
X.delete_edge(5,9)
X.delete_edge(5,10)
X.add_edge(4,9)
X.add_edge(4,10)
X.show()
hitting_time_matrix(X)
# Out:
# Graphics object consisting of 24 graphics primitives
# [ 0  1  4  9 16 33 54 37 37 37 37 54]
# [21  0  3  8 15 32 53 36 36 36 36 53]
# [40 19  0  5 12 29 50 33 33 33 33 50]
# [57 36 17  0  7 24 45 28 28 28 28 45]
# [72 51 32 15  0 17 38 21 21 21 21 38]
# [77 56 37 20  5  0 21 26 26 26 26 21]
# [78 57 38 21  6  1  0 27 27 27 27 22]
# [73 52 33 16  1 18 39  0 22 22 22 39]
# [73 52 33 16  1 18 39 22  0 22 22 39]
# [73 52 33 16  1 18 39 22 22  0 22 39]
# [73 52 33 16  1 18 39 22 22 22  0 39]
# [78 57 38 21  6  1 22 27 27 27 27  0]

# %%
min_pessimal(X)
# Out:
# 16

# %%
W = X.copy()
W.delete_edge(5,11)
W.add_edge(4,11)
W.show()
hitting_time_matrix(W)
# Out:
# Graphics object consisting of 24 graphics primitives
# [ 0  1  4  9 16 35 56 37 37 37 37 37]
# [21  0  3  8 15 34 55 36 36 36 36 36]
# [40 19  0  5 12 31 52 33 33 33 33 33]
# [57 36 17  0  7 26 47 28 28 28 28 28]
# [72 51 32 15  0 19 40 21 21 21 21 21]
# [75 54 35 18  3  0 21 24 24 24 24 24]
# [76 55 36 19  4  1  0 25 25 25 25 25]
# [73 52 33 16  1 20 41  0 22 22 22 22]
# [73 52 33 16  1 20 41 22  0 22 22 22]
# [73 52 33 16  1 20 41 22 22  0 22 22]
# [73 52 33 16  1 20 41 22 22 22  0 22]
# [73 52 33 16  1 20 41 22 22 22 22  0]

# %%
min_pessimal(W)
# Out:
# 16

# %%
V = W.copy()
V.delete_edge(4,7)
V.delete_edge(4,8)
V.delete_edge(4,9)
V.delete_edge(4,10)
V.delete_edge(4,11)
V.add_edge(3,7)
V.add_edge(3,8)
V.add_edge(3,9)
V.add_edge(3,10)
V.add_edge(3,11)
V.show()
hitting_time_matrix(V)
# Out:
# Graphics object consisting of 24 graphics primitives
# [ 0  1  4  9 26 45 66 30 30 30 30 30]
# [21  0  3  8 25 44 65 29 29 29 29 29]
# [40 19  0  5 22 41 62 26 26 26 26 26]
# [57 36 17  0 17 36 57 21 21 21 21 21]
# [62 41 22  5  0 19 40 26 26 26 26 26]
# [65 44 25  8  3  0 21 29 29 29 29 29]
# [66 45 26  9  4  1  0 30 30 30 30 30]
# [58 37 18  1 18 37 58  0 22 22 22 22]
# [58 37 18  1 18 37 58 22  0 22 22 22]
# [58 37 18  1 18 37 58 22 22  0 22 22]
# [58 37 18  1 18 37 58 22 22 22  0 22]
# [58 37 18  1 18 37 58 22 22 22 22  0]

# %%
min_pessimal(V)
# Out:
# 9

# %% [markdown]
# ## 6/15:

# %% [markdown]
# ### Commute Time Matrices

# %%
for i in tree_generator(8,3):
    show(Graph(i))
    print(commute_time_matrix(i))
    print("-----")
# Out:
# Graphics object consisting of 16 graphics primitives
# [ 0 14 28 28 28 14 14 14]
# [14  0 14 14 14 28 28 28]
# [28 14  0 28 28 42 42 42]
# [28 14 28  0 28 42 42 42]
# [28 14 28 28  0 42 42 42]
# [14 28 42 42 42  0 28 28]
# [14 28 42 42 42 28  0 28]
# [14 28 42 42 42 28 28  0]
# -----
# Graphics object consisting of 16 graphics primitives
# [ 0 14 28 28 14 14 14 14]
# [14  0 14 14 28 28 28 28]
# [28 14  0 28 42 42 42 42]
# [28 14 28  0 42 42 42 42]
# [14 28 42 42  0 28 28 28]
# [14 28 42 42 28  0 28 28]
# [14 28 42 42 28 28  0 28]
# [14 28 42 42 28 28 28  0]
# -----
# Graphics object consisting of 16 graphics primitives
# [ 0 14 28 14 14 14 14 14]
# [14  0 14 28 28 28 28 28]
# [28 14  0 42 42 42 42 42]
# [14 28 42  0 28 28 28 28]
# [14 28 42 28  0 28 28 28]
# [14 28 42 28 28  0 28 28]
# [14 28 42 28 28 28  0 28]
# [14 28 42 28 28 28 28  0]
# -----

# %%
for i in tree_generator(8,5):
    show(Graph(i))
    print(i)
    print(commute_time_matrix(i))
    print("-----")
# Out:
# Graphics object consisting of 16 graphics primitives
# GhI?GG
# [ 0 14 28 42 42 14 28 28]
# [14  0 14 28 28 28 42 42]
# [28 14  0 14 14 42 56 56]
# [42 28 14  0 28 56 70 70]
# [42 28 14 28  0 56 70 70]
# [14 28 42 56 56  0 14 14]
# [28 42 56 70 70 14  0 28]
# [28 42 56 70 70 14 28  0]
# -----
# Graphics object consisting of 16 graphics primitives
# GhQ?GG
# [ 0 14 28 42 28 14 28 28]
# [14  0 14 28 14 28 42 42]
# [28 14  0 14 28 42 56 56]
# [42 28 14  0 42 56 70 70]
# [28 14 28 42  0 42 56 56]
# [14 28 42 56 42  0 14 14]
# [28 42 56 70 56 14  0 28]
# [28 42 56 70 56 14 28  0]
# -----
# Graphics object consisting of 16 graphics primitives
# GhQ?K?
# [ 0 14 28 42 28 14 28 14]
# [14  0 14 28 14 28 42 28]
# [28 14  0 14 28 42 56 42]
# [42 28 14  0 42 56 70 56]
# [28 14 28 42  0 42 56 42]
# [14 28 42 56 42  0 14 28]
# [28 42 56 70 56 14  0 42]
# [14 28 42 56 42 28 42  0]
# -----
# Graphics object consisting of 16 graphics primitives
# Gh_GOO
# [ 0 14 28 42 14 28 28 28]
# [14  0 14 28 28 42 42 42]
# [28 14  0 14 42 56 56 56]
# [42 28 14  0 56 70 70 70]
# [14 28 42 56  0 14 14 14]
# [28 42 56 70 14  0 28 28]
# [28 42 56 70 14 28  0 28]
# [28 42 56 70 14 28 28  0]
# -----
# Graphics object consisting of 16 graphics primitives
# Gh_GS?
# [ 0 14 28 42 14 28 28 14]
# [14  0 14 28 28 42 42 28]
# [28 14  0 14 42 56 56 42]
# [42 28 14  0 56 70 70 56]
# [14 28 42 56  0 14 14 28]
# [28 42 56 70 14  0 28 42]
# [28 42 56 70 14 28  0 42]
# [14 28 42 56 28 42 42  0]
# -----
# Graphics object consisting of 16 graphics primitives
# Gh_K?C
# [ 0 14 28 42 14 28 14 28]
# [14  0 14 28 28 42 28 42]
# [28 14  0 14 42 56 42 56]
# [42 28 14  0 56 70 56 70]
# [14 28 42 56  0 14 28 42]
# [28 42 56 70 14  0 42 56]
# [14 28 42 56 28 42  0 14]
# [28 42 56 70 42 56 14  0]
# -----
# Graphics object consisting of 16 graphics primitives
# Gh_KC?
# [ 0 14 28 42 14 28 14 14]
# [14  0 14 28 28 42 28 28]
# [28 14  0 14 42 56 42 42]
# [42 28 14  0 56 70 56 56]
# [14 28 42 56  0 14 28 28]
# [28 42 56 70 14  0 42 42]
# [14 28 42 56 28 42  0 28]
# [14 28 42 56 28 42 28  0]
# -----

# %%
A = Graph('Gh_GOO')
commute_time(A,7,0)
hitting_time_matrix(A)
# Out:
# [ 0  9 20 33  7 20 20 20]
# [ 5  0 11 24 12 25 25 25]
# [ 8  3  0 13 15 28 28 28]
# [ 9  4  1  0 16 29 29 29]
# [ 7 16 27 40  0 13 13 13]
# [ 8 17 28 41  1  0 14 14]
# [ 8 17 28 41  1 14  0 14]
# [ 8 17 28 41  1 14 14  0]

# %%
B = Graph('Gh_GS?')
commute_time(B,6,0)
hitting_time_matrix(B)
# Out:
# [ 0  9 20 33  9 22 22 13]
# [ 5  0 11 24 14 27 27 18]
# [ 8  3  0 13 17 30 30 21]
# [ 9  4  1  0 18 31 31 22]
# [ 5 14 25 38  0 13 13 18]
# [ 6 15 26 39  1  0 14 19]
# [ 6 15 26 39  1 14  0 19]
# [ 1 10 21 34 10 23 23  0]

# %%
for i in tree_generator(8,4):
    show(Graph(i))
    print(i)
    print(commute_time_matrix(i))
    print("-----")
# Out:
# Graphics object consisting of 16 graphics primitives
# GiPC?C
# [ 0 14 28 28 28 28 14 28]
# [14  0 14 14 14 14 28 42]
# [28 14  0 28 28 28 42 56]
# [28 14 28  0 28 28 42 56]
# [28 14 28 28  0 28 42 56]
# [28 14 28 28 28  0 42 56]
# [14 28 42 42 42 42  0 14]
# [28 42 56 56 56 56 14  0]
# -----
# Graphics object consisting of 16 graphics primitives
# GiQ?GG
# [ 0 14 28 28 28 14 28 28]
# [14  0 14 14 14 28 42 42]
# [28 14  0 28 28 42 56 56]
# [28 14 28  0 28 42 56 56]
# [28 14 28 28  0 42 56 56]
# [14 28 42 42 42  0 14 14]
# [28 42 56 56 56 14  0 28]
# [28 42 56 56 56 14 28  0]
# -----
# Graphics object consisting of 16 graphics primitives
# GiQ?K?
# [ 0 14 28 28 28 14 28 14]
# [14  0 14 14 14 28 42 28]
# [28 14  0 28 28 42 56 42]
# [28 14 28  0 28 42 56 42]
# [28 14 28 28  0 42 56 42]
# [14 28 42 42 42  0 14 28]
# [28 42 56 56 56 14  0 42]
# [14 28 42 42 42 28 42  0]
# -----
# Graphics object consisting of 16 graphics primitives
# Gi_GS?
# [ 0 14 28 28 14 28 28 14]
# [14  0 14 14 28 42 42 28]
# [28 14  0 28 42 56 56 42]
# [28 14 28  0 42 56 56 42]
# [14 28 42 42  0 14 14 28]
# [28 42 56 56 14  0 28 42]
# [28 42 56 56 14 28  0 42]
# [14 28 42 42 28 42 42  0]
# -----
# Graphics object consisting of 16 graphics primitives
# Gi_K?C
# [ 0 14 28 28 14 28 14 28]
# [14  0 14 14 28 42 28 42]
# [28 14  0 28 42 56 42 56]
# [28 14 28  0 42 56 42 56]
# [14 28 42 42  0 14 28 42]
# [28 42 56 56 14  0 42 56]
# [14 28 42 42 28 42  0 14]
# [28 42 56 56 42 56 14  0]
# -----
# Graphics object consisting of 16 graphics primitives
# Gi_KC?
# [ 0 14 28 28 14 28 14 14]
# [14  0 14 14 28 42 28 28]
# [28 14  0 28 42 56 42 42]
# [28 14 28  0 42 56 42 42]
# [14 28 42 42  0 14 28 28]
# [28 42 56 56 14  0 42 42]
# [14 28 42 42 28 42  0 28]
# [14 28 42 42 28 42 28  0]
# -----
# Graphics object consisting of 16 graphics primitives
# GkE?K?
# [ 0 14 28 14 28 14 28 14]
# [14  0 14 28 42 28 42 28]
# [28 14  0 42 56 42 56 42]
# [14 28 42  0 14 28 42 28]
# [28 42 56 14  0 42 56 42]
# [14 28 42 28 42  0 14 28]
# [28 42 56 42 56 14  0 42]
# [14 28 42 28 42 28 42  0]
# -----
# Graphics object consisting of 16 graphics primitives
# GkECC?
# [ 0 14 28 14 28 14 14 14]
# [14  0 14 28 42 28 28 28]
# [28 14  0 42 56 42 42 42]
# [14 28 42  0 14 28 28 28]
# [28 42 56 14  0 42 42 42]
# [14 28 42 28 42  0 28 28]
# [14 28 42 28 42 28  0 28]
# [14 28 42 28 42 28 28  0]
# -----

# %%
for i in tree_generator(8,5):
    show(Graph(i))
    print(i)
    print(commute_time_matrix(i))
    print("-----")
# Out:
# Graphics object consisting of 16 graphics primitives
# GhI?GG
# [ 0 14 28 42 42 14 28 28]
# [14  0 14 28 28 28 42 42]
# [28 14  0 14 14 42 56 56]
# [42 28 14  0 28 56 70 70]
# [42 28 14 28  0 56 70 70]
# [14 28 42 56 56  0 14 14]
# [28 42 56 70 70 14  0 28]
# [28 42 56 70 70 14 28  0]
# -----
# Graphics object consisting of 16 graphics primitives
# GhQ?GG
# [ 0 14 28 42 28 14 28 28]
# [14  0 14 28 14 28 42 42]
# [28 14  0 14 28 42 56 56]
# [42 28 14  0 42 56 70 70]
# [28 14 28 42  0 42 56 56]
# [14 28 42 56 42  0 14 14]
# [28 42 56 70 56 14  0 28]
# [28 42 56 70 56 14 28  0]
# -----
# Graphics object consisting of 16 graphics primitives
# GhQ?K?
# [ 0 14 28 42 28 14 28 14]
# [14  0 14 28 14 28 42 28]
# [28 14  0 14 28 42 56 42]
# [42 28 14  0 42 56 70 56]
# [28 14 28 42  0 42 56 42]
# [14 28 42 56 42  0 14 28]
# [28 42 56 70 56 14  0 42]
# [14 28 42 56 42 28 42  0]
# -----
# Graphics object consisting of 16 graphics primitives
# Gh_GOO
# [ 0 14 28 42 14 28 28 28]
# [14  0 14 28 28 42 42 42]
# [28 14  0 14 42 56 56 56]
# [42 28 14  0 56 70 70 70]
# [14 28 42 56  0 14 14 14]
# [28 42 56 70 14  0 28 28]
# [28 42 56 70 14 28  0 28]
# [28 42 56 70 14 28 28  0]
# -----
# Graphics object consisting of 16 graphics primitives
# Gh_GS?
# [ 0 14 28 42 14 28 28 14]
# [14  0 14 28 28 42 42 28]
# [28 14  0 14 42 56 56 42]
# [42 28 14  0 56 70 70 56]
# [14 28 42 56  0 14 14 28]
# [28 42 56 70 14  0 28 42]
# [28 42 56 70 14 28  0 42]
# [14 28 42 56 28 42 42  0]
# -----
# Graphics object consisting of 16 graphics primitives
# Gh_K?C
# [ 0 14 28 42 14 28 14 28]
# [14  0 14 28 28 42 28 42]
# [28 14  0 14 42 56 42 56]
# [42 28 14  0 56 70 56 70]
# [14 28 42 56  0 14 28 42]
# [28 42 56 70 14  0 42 56]
# [14 28 42 56 28 42  0 14]
# [28 42 56 70 42 56 14  0]
# -----
# Graphics object consisting of 16 graphics primitives
# Gh_KC?
# [ 0 14 28 42 14 28 14 14]
# [14  0 14 28 28 42 28 28]
# [28 14  0 14 42 56 42 42]
# [42 28 14  0 56 70 56 56]
# [14 28 42 56  0 14 28 28]
# [28 42 56 70 14  0 42 42]
# [14 28 42 56 28 42  0 28]
# [14 28 42 56 28 42 28  0]
# -----
